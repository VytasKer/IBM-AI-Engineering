# %% [markdown]
# # Fashion-MNIST Project

# %% [markdown]
# ### Libraries

# %%
# %pip install torch
# %pip install torchvision
# %pip install matplotlib
# Out:
# Requirement already satisfied: torch in c:\users\vytask\anaconda3\lib\site-packages (2.5.1)
# Requirement already satisfied: filelock in c:\users\vytask\anaconda3\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\vytask\anaconda3\lib\site-packages (from torch) (4.11.0)
# Requirement already satisfied: networkx in c:\users\vytask\anaconda3\lib\site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\vytask\anaconda3\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\vytask\anaconda3\lib\site-packages (from torch) (2024.3.1)
# Requirement already satisfied: setuptools in c:\users\vytask\anaconda3\lib\site-packages (from torch) (69.5.1)
# Requirement already satisfied: sympy==1.13.1 in c:\users\vytask\anaconda3\lib\site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\vytask\anaconda3\lib\site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\vytask\anaconda3\lib\site-packages (from jinja2->torch) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.
# Collecting torchvisionNote: you may need to restart the kernel to use updated packages.
#
#   Downloading torchvision-0.20.1-cp312-cp312-win_amd64.whl.metadata (6.2 kB)
# Requirement already satisfied: numpy in c:\users\vytask\anaconda3\lib\site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: torch==2.5.1 in c:\users\vytask\anaconda3\lib\site-packages (from torchvision) (2.5.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\vytask\anaconda3\lib\site-packages (from torchvision) (10.3.0)
# Requirement already satisfied: filelock in c:\users\vytask\anaconda3\lib\site-packages (from torch==2.5.1->torchvision) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\vytask\anaconda3\lib\site-packages (from torch==2.5.1->torchvision) (4.11.0)
# Requirement already satisfied: networkx in c:\users\vytask\anaconda3\lib\site-packages (from torch==2.5.1->torchvision) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\vytask\anaconda3\lib\site-packages (from torch==2.5.1->torchvision) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\vytask\anaconda3\lib\site-packages (from torch==2.5.1->torchvision) (2024.3.1)
# Requirement already satisfied: setuptools in c:\users\vytask\anaconda3\lib\site-packages (from torch==2.5.1->torchvision) (69.5.1)
# Requirement already satisfied: sympy==1.13.1 in c:\users\vytask\anaconda3\lib\site-packages (from torch==2.5.1->torchvision) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\vytask\anaconda3\lib\site-packages (from sympy==1.13.1->torch==2.5.1->torchvision) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\vytask\anaconda3\lib\site-packages (from jinja2->torch==2.5.1->torchvision) (2.1.3)
# Downloading torchvision-0.20.1-cp312-cp312-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    -- ------------------------------------- 0.1/1.6 MB 762.6 kB/s eta 0:00:02
#    --- ------------------------------------ 0.1/1.6 MB 901.1 kB/s eta 0:00:02
#    ------ --------------------------------- 0.2/1.6 MB 1.3 MB/s eta 0:00:02
#    --------- ------------------------------ 0.4/1.6 MB 1.6 MB/s eta 0:00:01
#    --------------- ------------------------ 0.6/1.6 MB 2.1 MB/s eta 0:00:01
#    ------------------- -------------------- 0.8/1.6 MB 2.3 MB/s eta 0:00:01
#    -------------------------- ------------- 1.0/1.6 MB 2.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.2/1.6 MB 2.8 MB/s eta 0:00:01
#    ------------------------------------ --- 1.4/1.6 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 3.1 MB/s eta 0:00:00
# Installing collected packages: torchvision
# Successfully installed torchvision-0.20.1
# Requirement already satisfied: matplotlib in c:\users\vytask\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vytask\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\vytask\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vytask\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\vytask\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in c:\users\vytask\anaconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\vytask\anaconda3\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\vytask\anaconda3\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\vytask\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vytask\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\vytask\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# PyTorch Modules you need for this lab

from torch.utils.data import Dataset, DataLoader

from torchvision import transforms
import torch 
import torch.nn as nn
import torchvision.transforms as transforms
import torchvision.datasets as dsets
torch.manual_seed(0)

# Other non-PyTorch Modules
from matplotlib.pyplot import imshow
import matplotlib.pylab as plt

from PIL import Image

# %% [markdown]
# ### Helper functions

# %%
def show_data(data_sample):
    plt.imshow(data_sample[0].numpy().reshape(IMAGE_SIZE, IMAGE_SIZE), cmap='gray')
    plt.title('y = '+ str(data_sample[1]))

# %% [markdown]
# ### Questions 1: Create a Dataset Class

# %%
IMAGE_SIZE = 16

transforms.Resize((IMAGE_SIZE, IMAGE_SIZE)),
transforms.ToTensor()
composed = transforms.Compose([transforms.Resize((IMAGE_SIZE, IMAGE_SIZE)), transforms.ToTensor()])

# %%
dataset_train = dsets.FashionMNIST(root= '.fashion/data', train=True, transform=composed,  download=True)
dataset_val = dsets.FashionMNIST(root= '.fashion/data', train=False, transform=composed,  download=True)
# Out:
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to .fashion/data\FashionMNIST\raw\train-images-idx3-ubyte.gz
# 100%|██████████| 26.4M/26.4M [00:06<00:00, 4.07MB/s]
# Extracting .fashion/data\FashionMNIST\raw\train-images-idx3-ubyte.gz to .fashion/data\FashionMNIST\raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to .fashion/data\FashionMNIST\raw\train-labels-idx1-ubyte.gz
# 100%|██████████| 29.5k/29.5k [00:00<00:00, 445kB/s]
# Extracting .fashion/data\FashionMNIST\raw\train-labels-idx1-ubyte.gz to .fashion/data\FashionMNIST\raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to .fashion/data\FashionMNIST\raw\t10k-images-idx3-ubyte.gz
# 100%|██████████| 4.42M/4.42M [00:01<00:00, 3.25MB/s]
# Extracting .fashion/data\FashionMNIST\raw\t10k-images-idx3-ubyte.gz to .fashion/data\FashionMNIST\raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to .fashion/data\FashionMNIST\raw\t10k-labels-idx1-ubyte.gz
# 100%|██████████| 5.15k/5.15k [00:00<?, ?B/s]
# Extracting .fashion/data\FashionMNIST\raw\t10k-labels-idx1-ubyte.gz to .fashion/data\FashionMNIST\raw

# %%
for n,data_sample in enumerate(dataset_val):

    show_data(data_sample)
    plt.show()
    if n==2:
        break

# %% [markdown]
# ### Questions 2

# %%
class CNN_batch(nn.Module):
    
    # Contructor
    def __init__(self, out_1=16, out_2=32, number_of_classes=10):
        super(CNN_batch, self).__init__()
        self.cnn1 = nn.Conv2d(in_channels=1, out_channels=out_1, kernel_size=5, padding=2)
        self.conv1_bn = nn.BatchNorm2d(out_1)

        self.maxpool1=nn.MaxPool2d(kernel_size=2)
        
        self.cnn2 = nn.Conv2d(in_channels=out_1, out_channels=out_2, kernel_size=5, stride=1, padding=2)
        self.conv2_bn = nn.BatchNorm2d(out_2)

        self.maxpool2=nn.MaxPool2d(kernel_size=2)
        self.fc1 = nn.Linear(out_2 * 4 * 4, number_of_classes)
        self.bn_fc1 = nn.BatchNorm1d(10)
    
    # Prediction
    def forward(self, x):
        x = self.cnn1(x)
        x=self.conv1_bn(x)
        x = torch.relu(x)
        x = self.maxpool1(x)
        x = self.cnn2(x)
        x=self.conv2_bn(x)
        x = torch.relu(x)
        x = self.maxpool2(x)
        x = x.view(x.size(0), -1)
        x = self.fc1(x)
        x=self.bn_fc1(x)
        return x

# %%
train_loader = torch.utils.data.DataLoader(dataset=dataset_train, batch_size=100)
test_loader = torch.utils.data.DataLoader(dataset=dataset_val, batch_size=100)

# %%
model = CNN_batch(out_1=16, out_2=32, number_of_classes=10)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.1)

# %%
import time
start_time = time.time()

cost_list=[]
accuracy_list=[]
N_test=len(dataset_val)
n_epochs=10
for epoch in range(n_epochs):
    cost=0
    model.train()
    for x, y in train_loader:
        optimizer.zero_grad()
        z = model(x)
        loss = criterion(z, y)
        loss.backward()
        optimizer.step()
        cost+=loss.item()
    correct=0
    #perform a prediction on the validation  data 
    model.eval()
    for x_test, y_test in test_loader:
        z = model(x_test)
        _, yhat = torch.max(z.data, 1)
        correct += (yhat == y_test).sum().item()
    accuracy = correct / N_test
    accuracy_list.append(accuracy)
    cost_list.append(cost)

# %%
fig, ax1 = plt.subplots()
color = 'tab:red'
ax1.plot(cost_list, color=color)
ax1.set_xlabel('epoch', color=color)
ax1.set_ylabel('Cost', color=color)
ax1.tick_params(axis='y', color=color)
    
ax2 = ax1.twinx()  
color = 'tab:blue'
ax2.set_ylabel('accuracy', color=color) 
ax2.set_xlabel('epoch', color=color)
ax2.plot( accuracy_list, color=color)
ax2.tick_params(axis='y', color=color)
fig.tight_layout()
